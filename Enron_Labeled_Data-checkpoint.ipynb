# %% [markdown]
# ### Import the labeld dataset AND list eligible accounts for fine-tuning
#
# ### Next step is: doc-embedding model?? With the doc-level labels...

# %%
import pandas as pd

emails_df = pd.read_csv("C:/Users/Margeum/Dropbox/DS projects/05. Email data/emails_in_csv/enron_05_17_2015_with_labels_v2.csv")
# Out:
# C:\Users\Margeum\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2714: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
emails_df.head()
emails_df["labeled"].describe()
517401-515699   #=1702
labeled_id = emails_df[emails_df["labeled"]==True]

# %%
len(labeled_id)
labeled_id.head()
# Out:
#       Unnamed: 0                                     Message-ID  \
# 379          379   <9831685.1075855725804.JavaMail.evans@thyme>
# 381          381  <21041312.1075855725847.JavaMail.evans@thyme>
# 2139        2139   <5907100.1075858639941.JavaMail.evans@thyme>
# 2140        2140  <26625142.1075858639964.JavaMail.evans@thyme>
# 2232        2232  <19730598.1075858642129.JavaMail.evans@thyme>
#
#                      Date                                    From  \
# 379   2001-03-15 14:45:00  frozenset({'phillip.allen@enron.com'})
# 381   2001-03-15 14:11:00  frozenset({'phillip.allen@enron.com'})
# 2139  2001-06-20 17:04:51       frozenset({'k..allen@enron.com'})
# 2140  2001-06-20 17:09:00       frozenset({'k..allen@enron.com'})
# 2232  2001-08-09 12:30:58       frozenset({'k..allen@enron.com'})
#
#                                                      To  \
# 379                 frozenset({'todd.burke@enron.com'})
# 381                 frozenset({'kim.bolton@enron.com'})
# ...

# %%
labeled_id[["Cat_1_level_1", "Cat_1_level_2", "Cat_2_level_1", "Cat_2_level_2", "Cat_3_level_1", "Cat_3_level_2",
          "Cat_4_level_1", "Cat_4_level_2", "Cat_5_level_1", "Cat_5_level_2", "Cat_6_level_1", "Cat_6_level_2"]].head(10)
# Out:
#       Cat_1_level_1  Cat_1_level_2  Cat_2_level_1  Cat_2_level_2  \
# 379             1.0            1.0            3.0            8.0
# 381             1.0            3.0            4.0           10.0
# 2139            1.0            4.0            2.0            2.0
# 2140            1.0            4.0            2.0            2.0
# 2232            1.0            4.0            2.0            2.0
# 2400            1.0            4.0            2.0            1.0
# 3901            1.0            5.0            2.0            1.0
# 3922            1.0            1.0            2.0            1.0
# 3928            1.0            1.0            1.0            3.0
# 4723            1.0            1.0            3.0            2.0
#
#       Cat_3_level_1  Cat_3_level_2  Cat_4_level_1  Cat_4_level_2  \
# 379             NaN            NaN            NaN            NaN
# 381             4.0           11.0            NaN            NaN
# ...

# %%
any(labeled_id["Cat_2_level_1"].fillna(0.0).astype(int) == 3] | labeled_id["Cat_2_level_1"].fillna(0.0).astype(int) == 3])
# Out:
#   File "<ipython-input-49-a6c702a788d2>", line 1
#     any(labeled_id["Cat_2_level_1"].fillna(0.0).astype(int) == 3] | labeled_id["Cat_2_level_1"].fillna(0.0).astype(int) == 3])
#                                                                 ^
# SyntaxError: invalid syntax

# %%
labeled_id_red = labeled_id[(labeled_id["Cat_1_level_1"].fillna(0.0).astype(int) == 3) | 
                        (labeled_id["Cat_2_level_1"].fillna(0.0).astype(int) == 3) |
                        (labeled_id["Cat_3_level_1"].fillna(0.0).astype(int) == 3) |
                        (labeled_id["Cat_4_level_1"].fillna(0.0).astype(int) == 3) |
                        (labeled_id["Cat_5_level_1"].fillna(0.0).astype(int) == 3) |
                        (labeled_id["Cat_6_level_1"].fillna(0.0).astype(int) == 3) |
                        (labeled_id["Cat_7_level_1"].fillna(0.0).astype(int) == 3) |
                        (labeled_id["Cat_8_level_1"].fillna(0.0).astype(int) == 3) |
                        (labeled_id["Cat_9_level_1"].fillna(0.0).astype(int) == 3) |
                        (labeled_id["Cat_10_level_1"].fillna(0.0).astype(int) == 3) |
                        (labeled_id["Cat_11_level_1"].fillna(0.0).astype(int) == 3) |
                        (labeled_id["Cat_12_level_1"].fillna(0.0).astype(int) == 3) 
                       ]

# %%
len(labeled_id_red)  # 879 emails
# Out:
# 879

# %%
labeled_id_red["Cat_1_level_1"] = labeled_id["Cat_1_level_1"].fillna(0.0).astype(int)
labeled_id_red["Cat_1_level_2"] = labeled_id["Cat_1_level_2"].fillna(0.0).astype(int)

labeled_id_red["Cat_2_level_1"] = labeled_id["Cat_2_level_1"].fillna(0.0).astype(int)
labeled_id_red["Cat_2_level_2"] = labeled_id["Cat_2_level_2"].fillna(0.0).astype(int)

labeled_id_red["Cat_3_level_1"] = labeled_id["Cat_3_level_1"].fillna(0.0).astype(int)
labeled_id_red["Cat_3_level_2"] = labeled_id["Cat_3_level_2"].fillna(0.0).astype(int)

labeled_id_red["Cat_4_level_1"] = labeled_id["Cat_4_level_1"].fillna(0.0).astype(int)
labeled_id_red["Cat_4_level_2"] = labeled_id["Cat_4_level_2"].fillna(0.0).astype(int)

labeled_id_red["Cat_5_level_1"] = labeled_id["Cat_5_level_1"].fillna(0.0).astype(int)
labeled_id_red["Cat_5_level_2"] = labeled_id["Cat_5_level_2"].fillna(0.0).astype(int)

labeled_id_red["Cat_6_level_1"] = labeled_id["Cat_6_level_1"].fillna(0.0).astype(int)
labeled_id_red["Cat_6_level_2"] = labeled_id["Cat_6_level_2"].fillna(0.0).astype(int)

labeled_id_red["Cat_7_level_1"] = labeled_id["Cat_7_level_1"].fillna(0.0).astype(int)
labeled_id_red["Cat_7_level_2"] = labeled_id["Cat_7_level_2"].fillna(0.0).astype(int)

labeled_id_red["Cat_8_level_1"] = labeled_id["Cat_8_level_1"].fillna(0.0).astype(int)
labeled_id_red["Cat_8_level_2"] = labeled_id["Cat_8_level_2"].fillna(0.0).astype(int)

labeled_id_red["Cat_9_level_1"] = labeled_id["Cat_9_level_1"].fillna(0.0).astype(int)
labeled_id_red["Cat_9_level_2"] = labeled_id["Cat_9_level_2"].fillna(0.0).astype(int)

labeled_id_red["Cat_10_level_1"] = labeled_id["Cat_10_level_1"].fillna(0.0).astype(int)
labeled_id_red["Cat_10_level_2"] = labeled_id["Cat_10_level_2"].fillna(0.0).astype(int)

labeled_id_red["Cat_11_level_1"] = labeled_id["Cat_11_level_1"].fillna(0.0).astype(int)
labeled_id_red["Cat_11_level_2"] = labeled_id["Cat_11_level_2"].fillna(0.0).astype(int)

labeled_id_red["Cat_12_level_1"] = labeled_id["Cat_12_level_1"].fillna(0.0).astype(int)
labeled_id_red["Cat_12_level_2"] = labeled_id["Cat_12_level_2"].fillna(0.0).astype(int)
# Out:
# C:\Users\Margeum\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Margeum\Anaconda2\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Margeum\Anaconda2\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# Out:
#         Unnamed: 0                                     Message-ID  \
# 379            379   <9831685.1075855725804.JavaMail.evans@thyme>
# 3922          3922    <860767.1075849626951.JavaMail.evans@thyme>
# 3928          3928  <17578964.1075849627055.JavaMail.evans@thyme>
# 4723          4723  <24049587.1075849626031.JavaMail.evans@thyme>
# 8769          8769  <12708474.1075863592189.JavaMail.evans@thyme>
# 8862          8862  <32285691.1075863729020.JavaMail.evans@thyme>
# 24803        24803   <4890112.1075845067403.JavaMail.evans@thyme>
# 35480        35480   <3301537.1075853084185.JavaMail.evans@thyme>
# 35743        35743   <8041754.1075853069648.JavaMail.evans@thyme>
# 37842        37842  <22321111.1075858309482.JavaMail.evans@thyme>
# 38629        38629   <5140735.1075840386341.JavaMail.evans@thyme>
# 38749        38749  <31649197.1075840380337.JavaMail.evans@thyme>
# 48009        48009   <3086394.1075860481599.JavaMail.evans@thyme>
# ...

# %%
label_dict = {}

primary = ['3.1', '3.2', '3.3', '3.4', '3.5', '3.6', '3.7', '3.8', '3.9', '3.10', '3.11', '3.12']

#for i in range(len(labeled_id_red)):
for i in range(len(labeled_id_red)):
    this_doc = []
    this_doc.append((str(labeled_id_red.iloc[i]["Cat_1_level_1"])+'.'+str(labeled_id_red.iloc[i]["Cat_1_level_2"])))
    this_doc.append((str(labeled_id_red.iloc[i]["Cat_2_level_1"])+'.'+str(labeled_id_red.iloc[i]["Cat_2_level_2"])))
    this_doc.append((str(labeled_id_red.iloc[i]["Cat_3_level_1"])+'.'+str(labeled_id_red.iloc[i]["Cat_3_level_2"])))
    this_doc.append((str(labeled_id_red.iloc[i]["Cat_4_level_1"])+'.'+str(labeled_id_red.iloc[i]["Cat_4_level_2"])))
    this_doc.append((str(labeled_id_red.iloc[i]["Cat_5_level_1"])+'.'+str(labeled_id_red.iloc[i]["Cat_5_level_2"])))
    this_doc.append((str(labeled_id_red.iloc[i]["Cat_6_level_1"])+'.'+str(labeled_id_red.iloc[i]["Cat_6_level_2"])))
    this_doc.append((str(labeled_id_red.iloc[i]["Cat_7_level_1"])+'.'+str(labeled_id_red.iloc[i]["Cat_7_level_2"])))
    this_doc.append((str(labeled_id_red.iloc[i]["Cat_8_level_1"])+'.'+str(labeled_id_red.iloc[i]["Cat_8_level_2"])))
    this_doc.append((str(labeled_id_red.iloc[i]["Cat_9_level_1"])+'.'+str(labeled_id_red.iloc[i]["Cat_9_level_2"])))
    this_doc.append((str(labeled_id_red.iloc[i]["Cat_10_level_1"])+'.'+str(labeled_id_red.iloc[i]["Cat_10_level_2"])))
    this_doc.append((str(labeled_id_red.iloc[i]["Cat_11_level_1"])+'.'+str(labeled_id_red.iloc[i]["Cat_11_level_2"])))
    this_doc.append((str(labeled_id_red.iloc[i]["Cat_12_level_1"])+'.'+str(labeled_id_red.iloc[i]["Cat_12_level_2"])))
    this_doc = [x for x in this_doc if x in primary]
    label_dict.update( {labeled_id.iloc[i]["Message-ID"]: [this_doc, labeled_id.iloc[i]["content"]]} )
    # from the this_doc -- drop item

# %%
label_dict_dt = pd.DataFrame.from_dict(label_dict, orient = 'index', columns = ["topic", "content"])

# %%
label_dict_dt.head(10)  ## USE THIS DATAFRAME to connect with user name....
# Out:
#                                                     topic  \
# <16497606.1075863437765.JavaMail.evans@thyme>       [3.8]
# <10469240.1075863429356.JavaMail.evans@thyme>      [3.10]
# <14585290.1075842999386.JavaMail.evans@thyme>      [3.12]
# <14233574.1075847586939.JavaMail.evans@thyme>       [3.6]
# <16848822.1075853125247.JavaMail.evans@thyme>  [3.1, 3.6]
# <21372546.1075846179938.JavaMail.evans@thyme>       [3.9]
# <21409807.1075863426518.JavaMail.evans@thyme>       [3.9]
# <33228374.1075851641742.JavaMail.evans@thyme>       [3.2]
# <14294698.1075846173741.JavaMail.evans@thyme>       [3.6]
# <26804150.1075842955435.JavaMail.evans@thyme>  [3.3, 3.7]
#
#                                                                                          content
# <16497606.1075863437765.JavaMail.evans@thyme>  Liz, An update on Frank's availability at Stan...
# <10469240.1075863429356.JavaMail.evans@thyme>  Greetings from London. What do you think about...
# ...

# %%
import os 

path = 'C:/Users/Margeum/Dropbox/DS projects/05. Email data/emails_in_csv'
os.chdir(path)

#from subprocess import check_output
#print(check_output(["ls", "."]).decode("utf8"))

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory


# Read the data into a DataFrame
emails_df = pd.read_csv('./emails.csv')

print(emails_df.shape)
emails_df.head()
#print len(emails_df)
# Out:
# (517401, 2)
#                        file                                            message
# 0     allen-p/_sent_mail/1.  Message-ID: <18782981.1075855378110.JavaMail.e...
# 1    allen-p/_sent_mail/10.  Message-ID: <15464986.1075855378456.JavaMail.e...
# 2   allen-p/_sent_mail/100.  Message-ID: <24216240.1075855687451.JavaMail.e...
# 3  allen-p/_sent_mail/1000.  Message-ID: <13505866.1075863688222.JavaMail.e...
# 4  allen-p/_sent_mail/1001.  Message-ID: <30922949.1075863688243.JavaMail.e...

# %%
emails_df['user'] = 'NaN'
emails_df['message_id'] = 'NaN'

for i in range(len(emails_df)):
    emails_df['user'][i] = emails_df["file"][i].split('/')[0]
    emails_df['message_id'][i] = emails_df["message"][i].split(': ')[1].split('\nDate')[0]

# %%
#emails_df = emails_df[["message_id", "user"]]
#emails_df = emails_df.set_index("message_id")

# %%
emails_df.tail()
# Out:
#                              file  \
# 517396  zufferli-j/sent_items/95.
# 517397  zufferli-j/sent_items/96.
# 517398  zufferli-j/sent_items/97.
# 517399  zufferli-j/sent_items/98.
# 517400  zufferli-j/sent_items/99.
#
#                                                   message user index  \
# 517396  Message-ID: <26807948.1075842029936.JavaMail.e...  NaN   NaN
# 517397  Message-ID: <25835861.1075842029959.JavaMail.e...  NaN   NaN
# 517398  Message-ID: <28979867.1075842029988.JavaMail.e...  NaN   NaN
# 517399  Message-ID: <22052556.1075842030013.JavaMail.e...  NaN   NaN
# 517400  Message-ID: <28618979.1075842030037.JavaMail.e...  NaN   NaN
#
#        message_id
# 517396        NaN
# 517397        NaN
# 517398        NaN
# 517399        NaN
# 517400        NaN

# %%
# Join the user info using message id
label_dict_dt = label_dict_dt.reset_index().join(emails_df.reset_index().set_index('message_id'), on= 'message_id', how='left',
                                              lsuffix='_left', rsuffix='_right')
# extract the first of the topic list -- treat it as a primary topic 
# Using 2500 list, count instance of each word in each topic!!! --> word by topic (count) matrix
# Then, words that appear in 1+ categories -- look at the distribution!!!
